# %% [markdown]
# # Notes
#
# Select GPU as runtime
#
# This is a continuation of our project Cap Recognizer
#
# The goal of this project is to classify 13 different types of caps / headwears commonly worn around the world. The types are following: <br/>
# 1. balaclava cap
# 2. baseball cap
# 3. beanie cap
# 4. boater hat
# 5. bowler hat
# 6. bucket hat
# 7. cowboy hat
# 8. flat cap
# 9. kepi cap
# 10. taqiyah cap
# 11. top hat
# 12. turban cap
# 13. visor cap

# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai

# %%
from fastai import *
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2025_ALL_Master_Course_Works/ALL_DL_CV/CV-Project-1_Cap-Recognizer
# Out:
# /content/drive/MyDrive/2025_ALL_Master_Course_Works/ALL_DL_CV/CV-Project-1_Cap-Recognizer

# %%
version = 0
img_path = 'test_images'
model_path = f'models/cap-recognizer-v{version}.pkl'

# %%
# Loading Model
model = load_learner('models/cap-recognizer-v0.pkl')

# %% [markdown]
# # Inference 1
#
# **Target:** balaclava cap

# %%
img = Image.open(f'{img_path}/test-1.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-1.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('balaclava cap',
#  tensor(0),
#  tensor([9.9987e-01, 6.6269e-07, 1.6117e-06, 2.0123e-07, 2.4408e-07, 4.4904e-06,
#          3.5538e-08, 7.0136e-07, 5.3772e-06, 3.6986e-07, 3.2128e-07, 1.1273e-04,
#          2.9853e-06]))

# %% [markdown]
# # Inference 2
#
# **Target:** baseball cap

# %%
img = Image.open(f'{img_path}/test-2.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('baseball cap',
#  tensor(1),
#  tensor([3.2849e-05, 4.3480e-01, 3.4898e-03, 2.1324e-04, 9.1640e-03, 1.3781e-01,
#          6.4103e-04, 4.0795e-01, 2.6923e-03, 7.3281e-04, 1.5195e-03, 9.0839e-04,
#          4.3644e-05]))

# %% [markdown]
# # Inference 3
# **Target:** beanie cap

# %%
img = Image.open(f'{img_path}/test-3.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=98x128>

# %%
# predicted right
model.predict(f'{img_path}/test-3.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('beanie cap',
#  tensor(2),
#  tensor([2.0530e-06, 2.5983e-05, 9.9991e-01, 1.8380e-07, 9.1560e-08, 3.2279e-06,
#          1.0451e-07, 3.4446e-06, 3.6340e-08, 5.2260e-05, 6.7932e-08, 4.0968e-07,
#          1.6817e-07]))

# %% [markdown]
# # Inference 4
# **Target:** boater hat

# %%
img = Image.open(f'{img_path}/test-4.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
# predicted right
model.predict(f'{img_path}/test-4.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('boater hat',
#  tensor(3),
#  tensor([2.1951e-06, 8.5931e-07, 3.5182e-07, 9.9769e-01, 2.1039e-03, 2.0836e-05,
#          3.6923e-05, 1.8639e-05, 2.5578e-05, 1.2384e-05, 8.3998e-05, 2.2020e-06,
#          1.7572e-07]))

# %% [markdown]
# # Inference 5
# **Target:** bowler hat

# %%
img = Image.open(f'{img_path}/test-5.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
# predicted right
model.predict(f'{img_path}/test-5.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('bowler hat',
#  tensor(4),
#  tensor([4.7574e-04, 5.4639e-02, 5.1594e-05, 2.9605e-03, 9.2396e-01, 2.4224e-03,
#          5.7438e-03, 8.6165e-03, 3.2819e-04, 2.8041e-04, 5.0704e-04, 5.3014e-06,
#          5.3419e-06]))

# %% [markdown]
# # Inference 6
# **Target:** bucket hat

# %%
img = Image.open(f'{img_path}/test-6.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-6.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('bucket hat',
#  tensor(5),
#  tensor([0.0182, 0.0256, 0.0137, 0.2049, 0.1312, 0.2225, 0.1568, 0.0033, 0.0045,
#          0.1750, 0.0073, 0.0157, 0.0211]))

# %% [markdown]
# # Inference 7
# **Target:** cowboy hat

# %%
img = Image.open(f'{img_path}/test-7.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
# predicted right
model.predict(f'{img_path}/test-7.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('cowboy hat',
#  tensor(6),
#  tensor([5.8508e-07, 1.2513e-06, 6.3773e-08, 9.6690e-06, 6.9228e-07, 2.1465e-07,
#          9.9997e-01, 1.0802e-05, 7.1033e-07, 9.7174e-09, 1.9739e-06, 6.8642e-09,
#          3.5635e-08]))

# %% [markdown]
# # Inference 8
# **Target:** flat cap

# %%
img = Image.open(f'{img_path}/test-8.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=98x128>

# %%
# predicted right
model.predict(f'{img_path}/test-8.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('flat cap',
#  tensor(7),
#  tensor([7.0201e-08, 1.7192e-05, 8.2747e-06, 1.9567e-06, 4.9335e-07, 7.3021e-07,
#          2.3301e-07, 9.9996e-01, 2.9892e-07, 1.0664e-05, 9.8475e-07, 1.3327e-07,
#          4.6305e-07]))

# %% [markdown]
# # Inference 9
# **Target:** kepi cap

# %%
img = Image.open(f'{img_path}/test-9.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
# predicted wrong
model.predict(f'{img_path}/test-9.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('boater hat',
#  tensor(3),
#  tensor([5.3433e-03, 5.4030e-04, 2.5215e-05, 5.7097e-01, 8.8135e-03, 5.2515e-02,
#          4.6723e-02, 5.6000e-03, 1.9933e-02, 2.8344e-01, 2.4895e-03, 3.2350e-03,
#          3.6516e-04]))

# %% [markdown]
# # Inference 10
# **Target:** taqiyah cap

# %%
img = Image.open(f'{img_path}/test-10.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-10.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('taqiyah cap',
#  tensor(9),
#  tensor([1.7700e-04, 1.9940e-04, 2.4477e-05, 5.7246e-06, 3.5721e-07, 4.2423e-04,
#          3.9564e-05, 7.7007e-05, 6.6304e-06, 9.9752e-01, 9.1348e-07, 1.5252e-03,
#          4.6073e-07]))

# %% [markdown]
# # Inference 11
# **Target:** top hat

# %%
img = Image.open(f'{img_path}/test-11.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-11.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('top hat',
#  tensor(10),
#  tensor([1.4292e-06, 9.5239e-06, 2.7941e-07, 9.7070e-07, 3.9779e-05, 1.7422e-03,
#          5.6028e-02, 1.0633e-03, 3.2505e-05, 8.5046e-06, 9.4106e-01, 6.4420e-07,
#          8.3567e-06]))

# %% [markdown]
# # Inference 12
# **Target:** turban cap

# %%
img = Image.open(f'{img_path}/test-12.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-12.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('turban cap',
#  tensor(11),
#  tensor([3.4854e-02, 8.9640e-03, 3.8768e-02, 2.6634e-03, 1.6540e-04, 3.7342e-03,
#          1.3512e-04, 4.1434e-04, 4.2252e-03, 5.4676e-04, 4.8316e-05, 8.9004e-01,
#          1.5440e-02]))

# %% [markdown]
# # Inference 13
# **Target:** visor cap

# %%
img = Image.open(f'{img_path}/test-13.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted wrong
model.predict(f'{img_path}/test-13.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('baseball cap',
#  tensor(1),
#  tensor([3.7321e-05, 5.7862e-01, 1.1995e-03, 7.4313e-04, 5.4201e-04, 3.5038e-03,
#          1.4976e-04, 2.0538e-02, 1.1645e-04, 2.3830e-04, 3.7205e-05, 8.2747e-03,
#          3.8600e-01]))

# %% [markdown]
# # Observation

# %% [markdown]
# Out of 13 category, model predicted wrong on kepi cap and visor cap
